# %% [markdown]
# # Video & Image Moderation API Server
# Notebook này sẽ khởi chạy model moderation và tạo một public URL thông qua ngrok để Mobile App (Flutter) có thể gọi tới.

# %%
# 1. Clone Source Code (Thay URL repo nếu cần thiết)
# !git clone https://github.com/TPH-Per/sensitive-detection.git
# %cd sensitive-detection/DA_DL_KPDL

# 2. Cài đặt các thư viện cần thiết
# !pip install fastapi uvicorn python-multipart pyngrok nest_asyncio gradio

# %%
# 3. Khởi chạy Moderation API Server
# Script colab_api.py đã được thiết lập ngrok_token.
# !python colab_api.py
