# %% [markdown]
# # AI Moderation Worker (Background Process)
# Chạy Notebook này, hệ thống sẽ liên tục kết nối với Firebase và kiểm duyệt ảnh/video ngay khi có bài viết mới!

# %%
# 1. Clone Source Code từ GitHub
# !git clone https://github.com/TPH-Per/sensitive-detection.git
# %cd /content/sensitive-detection/DA_DL_KPDL

# 2. Cài đặt các thư viện
# !pip install firebase-admin gradio

# %%
# 3. Khởi chạy Worker
# !python colab_worker.py
